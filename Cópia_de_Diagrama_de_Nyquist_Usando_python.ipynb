# %% [markdown]
# # Aluno : Victor Calebe Cavalcante de Macedo.
# ---
# Lista de controle 2 : 2021/1
# Link : [click here](https://drive.google.com/drive/u/1/folders/1jKZhwoMC_oQQNe8I4ay2xb-InKTde_1D)

# %%
# %%capture test 
# !pip install control

# %% [markdown]
# <h1>\begin{align}G(s) = \frac{1}{s-0.5}
# \end{align}

# %%
from pylab import plot
import control
from control import TransferFunction

s = TransferFunction.s
k = 1
G  = (1)/((s-0.5))

control.nyquist(G)

plot()
# Out:
# []

# %% [markdown]
# <h1>\begin{align}G(s) = \frac{1}{(s+1)(s-0.5)}
# \end{align}

# %%
G  = (1)/((s+1)*(s-0.5))
control.nyquist(G)

plot()
# Out:
# []

# %% [markdown]
# <h1>\begin{align}G(s) = \frac{s+1}{s-0.5}
# \end{align}

# %%
G  = (s+1)/(s-0.5)
control.nyquist(G)

plot()
# Out:
# []

# %% [markdown]
# <h1>\begin{align}G(s) = \frac{1}{s^{2}(s+1)(s+0.5)}
# \end{align}

# %%
G  = (1)/((s*s)*(s+1)*(s+0.5))

x = control.nyquist(G,label_freq=350)
plot()
print(G)
# Out:
#            1
# -----------------------
# s^4 + 1.5 s^3 + 0.5 s^2

# %% [markdown]
# <h1>\begin{align}G(s) = \frac{s}{(s+1)(s+0.5)}
# \end{align}

# %%
G  = (s)/((s+1)*(s+0.5))
control.nyquist(G)

plot()
# Out:
# []
